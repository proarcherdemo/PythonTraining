# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
data = pd.read_csv('Des_Sal.csv')
data
# Out:
#          Designation  Level   Salary
# 0     System Analyst      2    55010
# 1   Senior Engineer       3    60020
# 2  Senior Consultant      4    50030
# 3            Manager      5    90040
# 4      Group Manager      6   120050
# 5    Account Manager      7   160060
# 6   Business Partner      8   300060
# 7     Client Partner      9   400070
# 8               CFO      10   600080
# 9                CEO     11  1100090

# %%
X = data.iloc[:,1:-1]

# %%
X

# %%
y = data.iloc[:,-1]

# %%
plt.scatter(X,y,color='blue')
plt.xlabel('Level')
plt.ylabel('Sal')
plt.show()

# %%
linearModel = LinearRegression()
linearModel.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y, color='green')
plt.plot(X, linearModel.predict(X), color='red')
plt.show()

# %%
ptransformed = PolynomialFeatures(degree=7)
xpoly=ptransformed.fit_transform(X)
linearModel1 = LinearRegression()
linearModel1.fit(xpoly, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,y, color='green')
plt.plot(X, linearModel1.predict(xpoly), color='red')
plt.show()

# %%
linearModel.predict([[9.5]])
# Out:
# c:\Users\HP\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([577303.90909091])

# %%
linearModel1.predict(ptransformed.fit_transform([[9.5]]))
# Out:
# array([491597.44623506])

# %%
# House Prediction Data
