# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
# We will use Pima Indians Diabetes Database
# https://www.kaggle.com/uciml/pima-indians-diabetes-database/data

# Pima Indians => https://www.britannica.com/topic/Pima-people

col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
pima = pd.read_csv("logistic_diabetes.csv", header=None, names=col_names)

# %%
pima.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %% [raw]
# Features in Dataset
# ====================
#
# Pregnancies: Number of times pregnant
#
# Insulin: 2-Hour serum insulin (mu U/ml)
#
# BMI: Body mass index (weight in kg/(height in m)2)
#
# Age: Age (years)
#
# Glucose: Plasma glucose concentration over 2 hours in an oral glucose tolerance test
#
# BloodPressure: Diastolic blood pressure (mm Hg)
#
# DiabetesPedigreeFunction: Diabetes pedigree function (a function which scores likelihood of diabetes based on family history)
#
# SkinThickness: Triceps skin fold thickness (mm)
#
# Label: Class variable (0 if non-diabetic, 1 if diabetic)

# %%
#split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
X = pima[feature_cols] # Features
y = pima.label # Target variable

# %%
# split X and y into training and testing sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
print(X_train,X_test,y_train,y_test)
# Out:
#      pregnant  insulin   bmi  age  glucose  bp  pedigree
# 762         9        0  22.5   33       89  62     0.142
# 127         1       94  33.3   23      118  58     0.261
# 564         0        0  32.4   27       91  80     0.601
# 375        12      325  39.2   58      140  82     0.528
# 663         9      130  37.9   40      145  80     0.637
# 144         4      284  32.8   23      154  62     0.237
# 268         0        0  25.1   21      102  52     0.078
# 21          8        0  35.4   50       99  84     0.388
# 609         1      182  24.0   23      111  62     0.138
# 511         0      210  22.1   21      139  62     0.207
# 35          4      192  24.0   33      103  60     0.966
# 473         7        0  29.9   50      136  90     0.210
# 255         1        0  33.6   21      113  64     0.543
# 534         1       56  33.3   24       77  56     1.251
# 77          5        0  37.7   27       95  72     0.370
# 566         1       18  38.6   21       99  72     0.412
# 312         2       96  26.6   27      155  74     0.433
# 465         0      105  21.8   21      124  56     0.452
# 109         0       36  37.4   24       95  85     0.247
# 553         1       44  29.9   23       88  62     0.422
# 299         8        0  23.6   58      112  72     0.840
# 101         1        0  26.1   22      151  60     0.179
# 315         2       94  34.1   26      112  68     0.315
# 92          7       48  46.7   42       81  78     0.261
# 243         6      176  27.1   33      119  50     1.318
# 397         0        0  34.3   22      131  66     0.196
# 294         0        0  21.9   65      161  50     0.254
# 504         3        0  37.3   40       96  78     0.238
# 400         4        0  32.0   31       95  64     0.161
# 367         0        0  21.0   21      101  64     0.252
# ..        ...      ...   ...  ...      ...  ..       ...
# 518        13        0  32.8   41       76   60     0.180
# 632         2        0  26.2   23      111   60     0.343
# 524         3        0  31.6   24      125   58     0.151
# 536         0        0  29.6   46      105   90     0.197
# 597         1       25  27.8   21       89   24     0.559
# 462         8       49  35.3   39       74   70     0.705
# 17          7        0  29.6   31      107   74     0.254
# 739         1        0  39.5   42      102   74     0.293
# 263         3        0  32.4   63      142   80     0.200
# 241         4       88  33.1   22       91   70     0.446
# 344         8        0  36.8   57       95   72     0.485
# 302         5       42  35.8   35       77   82     0.156
# 704         4      100  28.4   27      110   76     0.118
# 240         1        0  29.2   21       91   64     0.192
# 170         6        0  30.8   36      102   82     0.180
# 691        13        0  42.3   44      158  114     0.257
# 490         2       66  36.8   24       83   65     0.629
# 45          0        0  42.0   25      180   66     1.893
# 750         4        0  31.2   22      136   70     1.182
# 62          5        0  25.0   36       44   62     0.587
# 78          0        0  43.2   26      131    0     0.270
# 366         6        0  27.6   29      124   72     0.368
# 301         2      135  31.6   25      144   58     0.422
# 382         1      182  25.4   21      109   60     0.947
# 140         3        0  21.1   55      128   78     0.268
# 463         5        0  27.6   37       88   78     0.258
#
# [192 rows x 7 columns] 762    0
# 127    0
# 564    0
# 375    1
# 663    1
# 144    0
# 268    0
# 21     0
# 609    0
# 511    0
# 35     0
# 473    0
# 255    1
# 534    0
# 77     0
# 566    0
# 312    1
# 465    0
# 109    1
# 553    0
# 299    0
# 101    0
# 315    0
# 92     0
# 243    1
# 397    1
# 294    0
# 504    0
# 400    1
# 367    0
#       ..
# 448    1
# 431    0
# 709    1
# 115    1
# 72     1
# 537    0
# 677    0
# 753    1
# 174    0
# 87     0
# 551    0
# 486    0
# 705    0
# 314    1
# 396    0
# 600    0
# 472    0
# 70     1
# 599    0
# 754    1
# 277    0
# 723    0
# 9      1
# 359    1
# 707    0
# 763    0
# 192    1
# 629    0
# 559    0
# 684    0
# Name: label, Length: 576, dtype: int64 661    1
# 122    0
# 113    0
# 14     1
# 529    0
# 103    0
# 338    1
# 588    1
# 395    0
# 204    0
# 31     1
# 546    1
# 278    0
# 593    0
# 737    0
# 202    0
# 175    1
# 55     0
# 479    0
# 365    0
# 417    1
# 577    1
# 172    0
# 352    0
# 27     0
# 605    0
# 239    0
# 744    0
# 79     0
# 496    0
#       ..
# 97     0
# 530    0
# 327    0
# 619    1
# 518    0
# 632    0
# 524    0
# 536    0
# 597    0
# 462    0
# 17     1
# 739    1
# 263    0
# 241    0
# 344    0
# 302    0
# 704    0
# 240    0
# 170    1
# 691    1
# 490    0
# 45     1
# 750    1
# 62     0
# 78     1
# 366    1
# 301    1
# 382    0
# 140    0
# 463    0
# Name: label, Length: 192, dtype: int64

# %%
# instantiate the model (using the default parameters)
#https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
reg = LogisticRegression()

# fit the model with data
reg.fit(X_train,y_train)

#
y_pred=reg.predict(X_test)

# %%
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[119,  11],
#        [ 26,  36]], dtype=int64)
