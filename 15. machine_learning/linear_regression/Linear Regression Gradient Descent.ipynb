# %%
# https://www.kaggle.com/datasets/spscientist/students-performance-in-exams

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# ..      ...            ...  ...           ...           ...
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [1000 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
plt.scatter(df['math score'], df['reading score'])
plt.show()

# %%
X = df[['math score']]   # independent variable
y = df['reading score']  # dependent variable
# Out:
# 0      72
# 1      90
# 2      95
# 3      57
# 4      78
#        ..
# 995    99
# 996    55
# 997    71
# 998    78
# 999    86
# Name: reading score, Length: 1000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import StandardScaler

# Linear Regression - OLS

linearModel = LinearRegression()
linearModel.fit(X_train, y_train)  # Train the model
y_pred = linearModel.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

print(r2)
print(mse)
# Out:
# 0.6654928290705224
# 79.93136564573577

# %%
sgdModel = SGDRegressor(max_iter=1000, learning_rate="constant", eta0=0.01, random_state=42)

sc = StandardScaler()
X_train_scaled = sc.fit_transform(X_train)
#y_train_scaled = sc.fit_transform(y_train)

print(X_train_scaled)

X_test_scaled = sc.fit_transform(X_test)
#y_test_scaled = sc.fit_transform(y_test)

sgdModel.fit(X_train_scaled, y_train)
y_pred_sgd= sgdModel.predict(X_test_scaled)

print(y_pred_sgd)
r2 = r2_score(y_test, y_pred_sgd)
mse = mean_squared_error(y_test, y_pred_sgd)

print(r2)
print(mse)
# Out:
# [[ 0.83421704]
#  [ 0.02625865]
#  [ 0.09358851]
#  [-1.32033867]
#  [ 0.36290798]
#  [-0.64704001]
#  [ 1.1035365 ]
#  [-0.37772055]
#  [ 2.1134845 ]
#  [-0.37772055]
#  [ 1.7095053 ]
#  [ 0.09358851]
#  [ 0.69955731]
#  [-0.04107122]
#  [-1.32033867]
#  [-0.10840108]
#  [ 0.09358851]
#  [-0.24306082]
#  [ 0.43023784]
#  [-1.656988  ]
#  [-0.31039068]
#  [ 0.09358851]
#  [ 0.02625865]
#  [-1.18567894]
#  [-2.12829707]
#  [ 0.09358851]
#  [ 0.16091838]
#  [ 0.22824825]
#  [ 0.90154691]
#  [ 0.56489758]
#  [-0.24306082]
#  [-0.04107122]
#  [ 0.49756771]
#  [-1.52232827]
#  [ 0.36290798]
#  [ 0.69955731]
#  [-1.38766854]
#  [ 0.36290798]
#  [ 1.03620664]
#  [-0.31039068]
#  [ 0.90154691]
#  [-0.84902961]
#  [ 0.83421704]
#  [ 1.37285597]
#  [-0.10840108]
#  [ 1.03620664]
#  [-1.79164774]
#  [ 1.77683517]
#  [-0.10840108]
#  [ 0.69955731]
#  [-1.38766854]
#  [ 1.44018584]
#  [-2.33028666]
#  [-1.8589776 ]
#  [ 1.3055261 ]
#  [-0.91635948]
#  [ 0.96887677]
#  [-1.72431787]
# ...
